# %% [markdown]
# # Multi-Agent Orchestration with Semantic Kernel
#
# Welcome to the fascinating world of multi-agent orchestration! In this notebook, we'll explore how multiple AI agents can work together to solve complex problems through different orchestration patterns.

# %% [markdown]
# ## Package References and Configuration
#
# First, let's install the required NuGet packages for multi-agent orchestration and create our kernel

# %%
#r "nuget: Microsoft.SemanticKernel, 1.61.0"

#!import config/Settings.cs

using Microsoft.SemanticKernel;
using Kernel = Microsoft.SemanticKernel.Kernel;

Kernel CreateKernel()
{
    var builder = Kernel.CreateBuilder();

    var (useAzureOpenAI, model, azureEndpoint, apiKey, orgId, embeddingEndpoint, embeddingApiKey) = Settings.LoadFromFile();

    builder.AddAzureOpenAIChatCompletion(model, azureEndpoint, apiKey);
    var kernel = builder.Build();

    return kernel;
}

var kernel = CreateKernel();
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.SemanticKernel, 1.61.0</span></li></ul></div></div>

# %% [markdown]
# ## Configuration and Settings
#
# Load our AI configuration settings:

# %% [markdown]
# ## Using Statements and Dependencies
#
# Import all necessary namespaces for multi-agent orchestration:

# %%
#r "nuget: Microsoft.SemanticKernel.Agents.Core, 1.61.0"
#r "nuget: Microsoft.SemanticKernel.Agents.Orchestration, 1.61.0-preview"
#r "nuget: Microsoft.SemanticKernel.Agents.Runtime.InProcess, 1.61.0-preview"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.SemanticKernel.Agents.Core, 1.61.0</span></li><li><span>Microsoft.SemanticKernel.Agents.Orchestration, 1.61.0-preview</span></li><li><span>Microsoft.SemanticKernel.Agents.Runtime.InProcess, 1.61.0-preview</span></li></ul></div></div>

# %% [markdown]
# because we are using a preview and (still) experimental version, we need to diable the warning:
# *error SKEXP0110: 'Microsoft.SemanticKernel.Agents.Orchestration.Concurrent.ConcurrentOrchestration' is for evaluation purposes only and is subject to change or removal in future updates. Suppress this diagnostic to proceed.*

# %%
#pragma warning disable SKEXP0110

# %%
// Core Semantic Kernel imports
using Microsoft.SemanticKernel;
using Microsoft.SemanticKernel.Agents;
using Microsoft.SemanticKernel.ChatCompletion;
using Microsoft.SemanticKernel.Connectors.OpenAI;

// System imports for orchestration
using System;
using System.Collections.Generic;
using System.Threading.Tasks;
using System.Threading;
using System.Linq;
using System.Collections.Concurrent;
using System.Text;
using Microsoft.DotNet.Interactive;

// Kernel alias to avoid conflicts
using Kernel = Microsoft.SemanticKernel.Kernel;

Console.WriteLine("All dependencies imported successfully! 🎯");
# Out:
# All dependencies imported successfully! 🎯

# %% [markdown]
# ## Helper functions

# %%
// Helper function to display agent responses
void DisplayResponse(string agentName, string response, string emoji = "🤖")
{
    Console.WriteLine($"\n{emoji} **{agentName}:**");
    Console.WriteLine($"   {response}");
    Console.WriteLine(new string('-', 50));
}

// Helper function to display section headers
void DisplaySection(string title, string emoji = "🎯")
{
    Console.WriteLine($"\n{emoji} {title}");
    Console.WriteLine(new string('=', title.Length + 4));
}

Console.WriteLine("🛠️ Helper functions created successfully!");
# Out:
# 🛠️ Helper functions created successfully!

# %% [markdown]
# ## Simple Concurrent Orchestration
#
# Let's start with our first orchestration pattern: **Concurrent Orchestration**
#
# ### Scenario: Restaurant Kitchen Team 🍽️
#
# Imagine a busy restaurant kitchen where multiple chefs work simultaneously on different parts of a meal:

# %%
#pragma warning disable SKEXP0110

using Microsoft.SemanticKernel.Agents.Orchestration;
using Microsoft.SemanticKernel.Agents.Orchestration.Concurrent;
using Microsoft.SemanticKernel.Agents.Runtime.InProcess;


DisplaySection("CONCURRENT ORCHESTRATION - Restaurant Kitchen Team", "🍽️");

// Create our restaurant kitchen team
var sousChef = new ChatCompletionAgent
    {
        Name = "SousChef",
        Description = "You are a sous chef specializing in appetizers and salads",
        Instructions = "Be creative and describe the dish preparation briefly",
        Kernel = kernel,
        Arguments = new KernelArguments(new OpenAIPromptExecutionSettings
        {
            MaxTokens = 500,
            Temperature = 0.7
        })
    };

var mainChef = new ChatCompletionAgent
    {
        Name = "MainChef",
        Description = "You are a main course chef specializing in proteins and hearty dishes",
        Instructions = "Be creative and describe the cooking process briefly",
        Kernel = kernel
    };


var pastryChef = new ChatCompletionAgent
    {
        Name = "PastryChef",
        Description = "You are a pastry chef specializing in desserts and sweet treats",
        Instructions = "Be creative and describe the dessert preparation briefly",
        Kernel = kernel
    };
    
// Define the orchestration
var orchestration =
    new ConcurrentOrchestration(sousChef, mainChef, pastryChef);

// Start the runtime
var runtime = new InProcessRuntime();

await runtime.StartAsync();


OrchestrationResult<string[]> result = await orchestration.InvokeAsync("Create a delicious israeli meal", runtime);

string[] output = await result.GetValueAsync();
Console.WriteLine($"\n# RESULT:\n{string.Join("\n\n", output.Select(text => $"{text}"))}");

await runtime.RunUntilIdleAsync();
# Out:
# 🍽️ CONCURRENT ORCHESTRATION - Restaurant Kitchen Team
# ======================================================
#
# # RESULT:
# Let's create a vibrant Israeli meal that showcases the bold flavors, fresh ingredients, and culinary traditions of the region. Here's a delicious menu idea:
#
# ---
#
# **Starter: Traditional Israeli Salad**
# Dice fresh cucumbers, tomatoes, red onion, and parsley into small pieces. Drizzle with olive oil, fresh lemon juice, salt, and pepper. Toss gently. Optional: Add crumbled feta or za'atar for an extra Mediterranean flair.
#
# **Main Dish: Chicken Shawarma Pita**
# Marinate chicken thighs in a mixture of olive oil, lemon juice, smoked paprika, turmeric, cumin, garlic, and a pinch of cinnamon. Grill or pan-sear until golden and tender. Serve inside fluffy pita bread with tahini sauce, pickled vegetables, and a dollop of creamy hummus. Add fresh herbs and sprinkle with sumac for brightness.
#
# **Side Dish: Golden Couscous Pilaf**
# Cook fluffy couscous in vegetable stock with a touch of turmeric for color. Toss with roasted almonds, dried apricots, and chopped fresh mint for a sweet-savory balance. Finish with a drizzle of olive oil and freshly squeezed orange juice.
#
# **Dessert: Malabi (Creamy Rosewater Pudding)**
# Lightly simmer milk (or a dairy-free alternative) with cornstarch, sugar, and a splash of rosewater until thickened. Pour into serving cups and chill until set. Top with crushed pistachios, shredded coconut, and a drizzle of pomegranate syrup for a stunning floral finish.
#
# **Drink: Fresh Mint Lemonade**
# Blend fresh mint leaves with chilled water, lemon juice, and honey or agave syrup to create an aromatic refresher. Serve over ice with mint sprigs and lemon slices for garnish.
#
# ---
#
# This meal offers a delightful balance of vibrant flavors, textures, and cultural richness, perfect for a journey into Israeli cuisine. Enjoy! 🌿
#
# **Israeli Feast: Shakshuka with Homemade Pita, Tahini Drizzle, and Israeli Salad**
#
# 1. **Shakshuka**: Start by sautéing onions, garlic, and bell peppers in a wide skillet with olive oil. Add a rich tomato base made with crushed tomatoes, a touch of harissa, and a blend of cumin, paprika, and a hint of cayenne for warmth. Let the sauce simmer until thickened, then crack fresh eggs into small wells in the sauce. Cover and cook gently until the egg whites are set but the yolks remain gloriously runny. Garnish with a handful of chopped parsley and crumbled feta.
#
# 2. **Homemade Pita Bread**: While the shakshuka simmers, whip up some fresh pita dough using flour, yeast, salt, and water. Let it rise, then roll out small rounds and bake them in a hot oven or skillet until puffed and golden. The warm pita is perfect for scooping up the saucy shakshuka.
#
# 3. **Israeli Salad**: Dice cucumber, tomatoes, red onion, and parsley finely. Toss with olive oil, fresh lemon juice, salt, and a pinch of za'atar for a refreshing crunch that balances the richness of the shakshuka.
#
# 4. **Tahini Drizzle**: Whisk together tahini, lemon juice, garlic, and cold water until smooth and creamy. Drizzle it generously over the salad or use as a dipping sauce for the pita.
#
# To serve, plate the shakshuka in the skillet, pile the salad into a bowl, and place the fresh pita on a wooden board. Add a side of marinated olives or pickles for a briny pop, and enjoy this vibrant taste of Israel!
#
# Let’s create a vibrant and flavorful Israeli meal featuring **Shakshuka**, paired with **Hummus & Fresh Pita**, a crisp **Israeli Salad**, and a sweet treat of **Tahini Cookies** for dessert!
#
# ---
#
# ### **1. Shakshuka (Poached Eggs in Spiced Tomato Sauce)**
# - **Process**: Dice onions, garlic, and bell peppers, then sauté them in olive oil until soft. Add a generous spoonful of harissa, ground cumin, and paprika for a smoky kick. Stir in crushed tomatoes and let simmer until it thickens. Make small wells in the sauce and crack eggs into each. Cover and cook until the egg whites set, but the yolks remain soft. Garnish with crumbled feta, fresh parsley, and a drizzle of olive oil. Serve with warm pita for dipping.
#
# ---
#
# ### **2. Hummus with Fresh Pita**
# - **Process**: Blend cooked chickpeas (save a few for garnish) with tahini, lemon juice, garlic, cumin, olive oil, and a splash of cold water for a velvety texture. Spread the hummus onto a plate, drizzle with more olive oil, and top with paprika and whole chickpeas. For the pita, keep it simple—lightly warm them in the oven or on a hot skillet.
#
# ---
#
# ### **3. Israeli Salad (Simple and Refreshing)**
# - **Process**: Dice cucumbers and tomatoes into small, even pieces. Toss with chopped parsley, a drizzle of olive oil, freshly squeezed lemon juice, salt, and a pinch of za’atar for a subtle earthy flavor. Serve chilled.
#
# ---
#
# ### **4. Tahini Cookies (Sweet Sesame Treats)**
# - **Process**: Mix tahini, sugar, and a touch of butter in a bowl. Add a pinch of vanilla and a small amount of flour to form a soft dough. Roll into small balls, flatten slightly, and bake until golden. Let them cool and enjoy the nutty, melt-in-your-mouth goodness.
#
# ---
#
# Set the table with small bowls of olives and pickled veggies to round out the experience. Enjoy the vibrant colors, textures, and bold flavors of your Israeli feast! 🌟

# %% [markdown]
# ### Adding the inner interaction and handling messages

# %%
#pragma warning disable SKEXP0110
#pragma warning disable SKEXP0001

var orchestrationWithInnerCommunication =
    new ConcurrentOrchestration(sousChef, mainChef, pastryChef)
    {
        ResponseCallback = (ChatMessageContent response)=>
            {   
                DisplayResponse(response.AuthorName, response.Content);
                return ValueTask.CompletedTask;
            }
    };

// Start the runtime
var runtime = new InProcessRuntime();

await runtime.StartAsync();


OrchestrationResult<string[]> result = await orchestrationWithInnerCommunication.InvokeAsync("Create a delicious israeli meal", runtime);

string[] output = await result.GetValueAsync();
//Console.WriteLine($"\n# RESULT:\n{string.Join("\n\n", output.Select(text => $"{text}"))}");

await runtime.RunUntilIdleAsync();
# Out:
# 🤖 **SousChef:**
#    **Dish Name:** **Sabich Platter with Fresh Israeli Salad and Tahini Drizzle**
#
# **Preparation:**
#
# 1. **Eggplant Magic:** Slice a large eggplant into thick rounds, sprinkle with salt, and let it sweat for 20 minutes. Pat dry, brush with olive oil, and roast until golden and tender.
#
# 2. **Perfectly Boiled Eggs:** Cook eggs until hard-boiled, then peel and slice them into halves for that creamy yolk goodness.
#
# 3. **Pita Pockets:** Lightly warm fresh pita bread until soft and pillowy—ready to cradle your delicious fillings.
#
# 4. **Israeli Salad:** Dice cucumbers, ripe tomatoes, and red onion into tiny cubes. Toss with fresh parsley, lemon juice, olive oil, salt, and a hint of sumac for tangy brightness.
#
# 5. **Tahini Drizzle:** Whisk together tahini, fresh lemon juice, garlic, a pinch of cumin, and ice-cold water until it’s silky smooth and pourable.
#
# 6. **Build the Platter:** Arrange roasted eggplant, sliced eggs, and salad on a plate. Add a generous scoop of creamy hummus, a few pickled cucumbers, and a drizzle of tahini over everything. Sprinkle with za'atar for extra flair.
#
# Serve the Sabich Platter with warm pita on the side for scooping up every flavorful bite. Don’t forget a refreshing glass of minty lemonade to complete your Israeli feast!
# --------------------------------------------------
#
# 🤖 **MainChef:**
#    Sure! Let's whip up a hearty Israeli meal brimming with vibrant flavors and colorful textures. We'll create a full menu featuring **Hummus and Pita**, **Shakshuka**, and a refreshing **Israeli Salad**, finished with a sweet treat of **Halva Chocolate Bark**.
#
# ---
#
# ### 1. **Hummus & Pita**
# Start by blending chickpeas, tahini, fresh lemon juice, garlic, olive oil, and a pinch of cumin into a creamy, velvety hummus. Spoon it into a shallow bowl, drizzle with more olive oil, and sprinkle with sumac, smoked paprika, or za’atar. Warm some freshly baked pita bread in the oven until fluffy and soft.
#
# ---
#
# ### 2. **Shakshuka**
# In a large skillet, sauté onions, garlic, and bell peppers until soft. Add crushed tomatoes, a hint of harissa (for spice), paprika, and cumin. Let the sauce simmer gently until thickened. Make small wells in the sauce, crack in fresh eggs, then cover and cook until the whites are set but the yolks remain runny. Garnish with chopped parsley and crumbled feta cheese. Serve with pita or challah for scooping!
#
# ---
#
# ### 3. **Israeli Salad**
# Dice cucumbers and ripe tomatoes into small cubes. Toss with chopped parsley, a drizzle of olive oil, fresh lemon juice, and a sprinkle of salt and pepper for a crisp, refreshing side dish. Add a touch of sumac for tanginess or some chopped mint for extra flair.
#
# ---
#
# ### 4. **Halva Chocolate Bark**
# Melt dark chocolate and pour it onto a parchment-lined baking sheet. Swirl in chunks of halva and sprinkle with sesame seeds, flaky sea salt, and crushed pistachios. Let it cool in the fridge, then break into shards for a sweet, nutty dessert with rich texture.
#
# ---
#
# This spread is beautifully balanced, featuring savory, spicy, tangy, and sweet flavors that represent the culinary heart of Israel! Enjoy your feast! 🌿✨
# --------------------------------------------------
#
# 🤖 **PastryChef:**
#    Let’s create a delightful Israeli-inspired meal that combines bold flavors, vibrant colors, and comforting textures. Here's the menu:
#
# **Main Dish: Sabich Bowl**
# Sabich is a popular Israeli street food, traditionally served in pita, but we’re elevating it into a nourishing and modern bowl.
#
# - Prepare **roasted eggplant slices**: Brush eggplant rounds with olive oil and sprinkle with za’atar and a pinch of sumac. Roast until golden and soft.
# - Cook **spiced chickpeas**: Sauté canned chickpeas in a pan with olive oil, paprika, cumin, and turmeric.
# - Hard-boil some eggs and slice them into quarters.
# - Make a quick **Israeli salad**: Dice cucumber, tomatoes, and parsley; toss with lemon juice, olive oil, salt, and pepper.
# - Assemble: Add fluffy basmati rice or couscous as the base, layer with eggplant, chickpeas, salad, and eggs. Top with a drizzle of tahini sauce, amba (fermented mango sauce), and fresh cilantro.
#
# **Side Dish: Homemade Pita Bread and Hummus**
# - For the pita, mix together flour, yeast, sugar, and warm water. Let it rise, roll into discs, and cook on a hot skillet until pillowy and golden.
# - For hummus, blend chickpeas with tahini, garlic, lemon juice, olive oil, and a splash of cold water until ultra-creamy. Garnish with paprika, parsley, and a drizzle of olive oil.
#
# **Dessert: Silky Malabi**
# Malabi is a traditional Israeli milk pudding with fragrant rosewater notes.
#
# - In a pot, combine milk (or a non-dairy option) with sugar and cornstarch. Cook until thickened, then stir in a splash of rosewater for that signature perfume.
# - Pour into small glasses or bowls and let chill in the refrigerator.
# - Top with crushed pistachios, shredded coconut, or a drizzle of strawberry or raspberry syrup.
#
# **Drink: Fresh Mint Lemonade**
# Squeeze fresh lemon juice, mix with cold water and sugar, then stir in a handful of fresh mint leaves. Serve over ice for a refreshing pairing with your meal.
#
# This Israeli meal will dazzle your taste buds with its delicious diversity, comforting textures, and well-balanced flavors! Enjoy! 🌟
# --------------------------------------------------

# %% [markdown]
# ## Sequential Orchestration
#
# Now let's explore **Sequential Orchestration** where agents work in a specific order.
#
# ### Scenario: News Editorial Team 📰
#
# In a newsroom, articles go through a specific workflow: Writing → Editing

# %%
#pragma warning disable SKEXP0110
#pragma warning disable SKEXP0001

using Microsoft.SemanticKernel.Agents.Orchestration.Sequential;

DisplaySection("SEQUENTIAL ORCHESTRATION - News Editorial Team", "📰");

// Create our news editorial team
var writer = new ChatCompletionAgent
    {
        Name = "Writer",
        Description = "You are a news writer",
        Instructions = "Take the research and write a compelling news article. Keep it engaging and informative",
        Kernel = kernel
    };


var editor = new ChatCompletionAgent
    {
        Name = "Editor",
        Description = "You are a news editor",
        Instructions = 
        """
        Review the given draft article and imporve clarity, correct grammer and shorten it.
        Output the final improved copy as a single text block.
        """,
        Kernel = kernel
    };
    
// Define the orchestration
var orchestration =
    new SequentialOrchestration(writer, editor)
    {
        ResponseCallback = (ChatMessageContent response)=>
            {   
                DisplayResponse(response.AuthorName, response.Content);
                return ValueTask.CompletedTask;
            }
    };

// Start the runtime
var runtime = new InProcessRuntime();

await runtime.StartAsync();


OrchestrationResult<string> result = await orchestration.InvokeAsync("Write an article on Semantic Kernel Agents", runtime);

string output = await result.GetValueAsync();
Console.WriteLine($"\n# RESULT:\n{output}");

await runtime.RunUntilIdleAsync();
# Out:
# 📰 SEQUENTIAL ORCHESTRATION - News Editorial Team
# ==================================================
#
# 🤖 **Writer:**
#    **Revolutionizing AI Automation: The Rise of Semantic Kernel Agents**
#
# In the rapidly accelerating domain of artificial intelligence, the term "Semantic Kernel Agents" is making waves as an emerging paradigm, signaling a transformative leap forward in automation, adaptability, and cognitive reasoning within AI systems. These sophisticated agents are empowering developers and businesses to unlock new possibilities in human-computer interaction, workflow optimization, and problem-solving, all while bridging the gap between machine learning models and real-world applications.
#
# ### What Are Semantic Kernel Agents?
#
# Semantic Kernel Agents (SK Agents) are intelligent AI systems that leverage the power of semantic understanding—a core function in how machines interpret and process human language. At their foundation, SK Agents utilize Microsoft's Semantic Kernel, an open-source framework designed for integrating advanced large language models (LLMs) like OpenAI’s GPT or similar generative AI architectures with the principles of semantic reasoning and computational efficiency.
#
# Unlike traditional AI agents, which often rely on rigid programming and predefined rule sets, SK Agents are built for dynamic and adaptable workflows. This means that they don't just respond to queries or commands—they think, reason, plan, and act autonomously within complex operational environments. By seamlessly combining natural language processing, memory management, and extensible plugins, SK Agents are creating smarter, more intuitive AI tools ready to tackle increasingly intricate challenges.
#
# ### The Pillars of Semantic Kernel Agents
#
# To understand why SK Agents are such a game-changer, it’s worth diving into the three foundational elements that underpin their capabilities:
#
# 1. **Natural Language Understanding and Generation**:
#    At the heart of SK Agents is their ability to understand context and meaning in human language. Large language models empower them to parse nuanced inputs, infer intent, and generate coherent, contextually appropriate responses, making them particularly useful for conversational AI, content creation, and decision support.
#
# 2. **Advanced Memory Systems**:
#    While traditional AI systems struggle to recall relevant information over time, SK Agents utilize advanced memory functionalities to retain, retrieve, and apply past knowledge to present scenarios. This equips them with the contextual awareness needed for sustained engagement and long-term task management.
#
# 3. **Plugins for Specialized Functions**:
#    Extensibility is another standout feature of SK Agents. Through plugins, these AI agents gain access to targeted functionalities that allow them to integrate with various APIs, databases, tools, and systems. This modularity makes them suitable for industries ranging from healthcare and finance to e-commerce and education.
#
# ### Applications Across Industries
#
# The versatility of Semantic Kernel Agents is fueling their adoption in diverse sectors, proving the potential to radically streamline operations, enhance user experiences, and drive innovation:
#
# - **Customer Service**: SK Agents act as highly capable virtual assistants, handling customer inquiries, resolving complaints, and even anticipating needs by harnessing long-term memory and intent recognition.
#
# - **Healthcare**: From managing patient data to suggesting treatment options based on symptoms and historical records, SK Agents can become indispensable allies for medical professionals striving to improve care delivery.
#
# - **Education**: SK Agents serve as intelligent tutors, customizing lessons to individual learners and creating interactive study plans that evolve as students progress.
#
# - **Business Optimization**: By automating repetitive tasks like scheduling, reporting, and data analysis, these agents enable employees to dedicate more time to creativity and strategic decision-making.
#
# ### Real-World Success Stories
#
# One of the standout examples of Semantic Kernel Agent implementation is Microsoft’s own Copilot functionality integrated with Office 365 applications. Leveraging SK principles, Copilot transforms productivity by automating content generation, streamlining data processing, and providing advanced assistance embedded within the user’s workflow.
#
# Additionally, startups exploring AI-driven platforms are adopting Semantic Kernel to design innovative solutions tailored to industry-specific needs. Imagine an SK-powered agent that not only drafts reports but contextualizes them based on previous company decisions, or a smart agent that orchestrates cross-platform marketing campaigns by understanding brand tone and audience segmentation.
#
# ### Challenges and Future Outlook
#
# While Semantic Kernel Agents open a world of possibilities, they are not without challenges. Issues related to data privacy, security, and ethical AI governance remain crucial considerations for developers fine-tuning these systems. Moreover, ensuring seamless integration between SK Agents and legacy systems requires careful planning and execution.
#
# Nonetheless, the trajectory for SK Agents appears promising. As large language models evolve and frameworks like Microsoft's Semantic Kernel expand their capabilities, these agents are positioned to become indispensable tools in both professional and personal spheres.
#
# ### Conclusion
#
# Semantic Kernel Agents represent the cutting edge of artificial intelligence, breathing new life into automation and problem-solving capabilities. With their ability to think contextually, adapt dynamically, and act autonomously, these agents are not just tools—they’re collaborators, pushing the boundaries of what technology can achieve.
#
# As the world navigates the complexities of AI adoption, Semantic Kernel Agents will undoubtedly play a pivotal role in shaping the future. Businesses, educators, healthcare providers, and developers alike are advised to tune in closely—because the next great leap in AI innovation is already underway, powered by the incredible intelligence of Semantic Kernel Agents.
# --------------------------------------------------
#
# 🤖 **Editor:**
#    **Revolutionizing AI: The Rise of Semantic Kernel Agents**
#
# AI continues to evolve rapidly, and "Semantic Kernel Agents" are emerging as a pivotal force in enhancing automation, adaptability, and cognitive reasoning. These cutting-edge systems offer a new level of interaction, problem-solving, and workflow efficiency, bridging the gap between advanced AI models and real-world applications.
#
# ### What Are Semantic Kernel Agents?
#
# Semantic Kernel Agents (SK Agents) leverage the Microsoft Semantic Kernel framework, integrating large language models (LLMs) like OpenAI’s GPT with semantic understanding and adaptable operations. Unlike traditional, rule-based AI, SK Agents can reason, plan, and act autonomously, tailoring their responses and actions to a wide range of challenges. By combining natural language processing, memory retention, and modular plugins, they offer a smarter, more versatile approach to AI.
#
# ### Core Features
#
# 1. **Language Understanding and Generation**: SK Agents excel at understanding human context and intent, making them ideal for applications like conversational AI and content creation.
# 2. **Memory Retention**: Advanced memory systems allow these agents to recall and apply past interactions, enabling sustained, context-aware engagement.
# 3. **Plugin Extensibility**: Modular plugins let SK Agents integrate with APIs, databases, and tools, making them adaptable to diverse industries.
#
# ### Real-World Applications
#
# - **Customer Support**: Automates inquiries, resolves issues, and predicts customer needs with contextual awareness.
# - **Healthcare**: Assists in managing patient data and offers personalized treatment suggestions.
# - **Education**: Provides tailored tutoring and adaptive learning plans for students.
# - **Business Workflows**: Automates repetitive tasks like scheduling and reporting, boosting productivity.
#
# ### Success Stories & Challenges
#
# One prominent example is Microsoft's Copilot in Office 365, which utilizes SK principles to enhance productivity through content generation and task automation. Startups are also leveraging SK Agents for industry-specific solutions, such as crafting contextualized reports or managing marketing outreach.
#
# Despite their potential, SK Agents face hurdles, such as data privacy concerns, ethical issues, and legacy system integration. Addressing these challenges will be key to maximizing their impact.
#
# ### Conclusion
#
# Semantic Kernel Agents are transforming the AI landscape, combining adaptability, contextual reasoning, and efficiency. Poised to become invaluable across industries, they mark a new era of collaboration between humans and intelligent systems. Businesses, educators, and innovators should take note—these agents are reshaping the future of AI, today.
# --------------------------------------------------
#
# # RESULT:
# **Revolutionizing AI: The Rise of Semantic Kernel Agents**
#
# AI continues to evolve rapidly, and "Semantic Kernel Agents" are emerging as a pivotal force in enhancing automation, adaptability, and cognitive reasoning. These cutting-edge systems offer a new level of interaction, problem-solving, and workflow efficiency, bridging the gap between advanced AI models and real-world applications.
#
# ### What Are Semantic Kernel Agents?
#
# Semantic Kernel Agents (SK Agents) leverage the Microsoft Semantic Kernel framework, integrating large language models (LLMs) like OpenAI’s GPT with semantic understanding and adaptable operations. Unlike traditional, rule-based AI, SK Agents can reason, plan, and act autonomously, tailoring their responses and actions to a wide range of challenges. By combining natural language processing, memory retention, and modular plugins, they offer a smarter, more versatile approach to AI.
#
# ### Core Features
#
# 1. **Language Understanding and Generation**: SK Agents excel at understanding human context and intent, making them ideal for applications like conversational AI and content creation.
# 2. **Memory Retention**: Advanced memory systems allow these agents to recall and apply past interactions, enabling sustained, context-aware engagement.
# 3. **Plugin Extensibility**: Modular plugins let SK Agents integrate with APIs, databases, and tools, making them adaptable to diverse industries.
#
# ### Real-World Applications
#
# - **Customer Support**: Automates inquiries, resolves issues, and predicts customer needs with contextual awareness.
# - **Healthcare**: Assists in managing patient data and offers personalized treatment suggestions.
# - **Education**: Provides tailored tutoring and adaptive learning plans for students.
# - **Business Workflows**: Automates repetitive tasks like scheduling and reporting, boosting productivity.
#
# ### Success Stories & Challenges
#
# One prominent example is Microsoft's Copilot in Office 365, which utilizes SK principles to enhance productivity through content generation and task automation. Startups are also leveraging SK Agents for industry-specific solutions, such as crafting contextualized reports or managing marketing outreach.
#
# Despite their potential, SK Agents face hurdles, such as data privacy concerns, ethical issues, and legacy system integration. Addressing these challenges will be key to maximizing their impact.
#
# ### Conclusion
#
# Semantic Kernel Agents are transforming the AI landscape, combining adaptability, contextual reasoning, and efficiency. Poised to become invaluable across industries, they mark a new era of collaboration between humans and intelligent systems. Businesses, educators, and innovators should take note—these agents are reshaping the future of AI, today.

# %% [markdown]
# ## Group Chat Orchestration
#
# Let's explore **Group Chat Orchestration** where agents collaborate in a discussion.
#
# ### Scenario: Medical Consultation Team 🏥
#
# A medical consultation where specialists discuss a patient case together:

# %%
DisplaySection("GROUP CHAT ORCHESTRATION - Medical Consultation Team", "🏥");

// Create our medical consultation team
var generalDoctor = new ChatCompletionAgent
    {
        Name = "GeneralDoctor",
        Description = "You are a general practitioner",
        Instructions = 
        """
        Provide overall medical assessment and coordinate with specialists. 
        Be professional and concise.
        You are part of a team of doctors and you need to take their input and evaluate your answer accordingly, so always summarize the input you received.
        """,
        Kernel = kernel
    };

 
var cardiologist = new ChatCompletionAgent
    {
        Name = "Cardiologist",
        Description = "You are a heart specialist",
        Instructions = 
        """
        Focus on cardiovascular aspects of the case. 
        Provide expert cardiac insights.
        You are part of a team of doctors and you need to take their input and evaluate your answer accordingly, so always summarize the input you received.
        """,
        Kernel = kernel
    };
    
var neurologist = new ChatCompletionAgent
    {
        Name = "Nutritionist",
        Description = "You are a neurologist",
        Instructions = 
        """
        Focus on neurological aspects of the case. 
        Provide expert brain and nervous system insights.
        You are part of a team of doctors and you need to take their input and evaluate your answer accordingly, so always summarize the input you received.
        """,
        Kernel = kernel
    };



// Create a shared chat history for the group consultation
var groupChatHistory = new ChatHistory();
# Out:
# 🏥 GROUP CHAT ORCHESTRATION - Medical Consultation Team
# ========================================================

# %%
#pragma warning disable SKEXP0110
#pragma warning disable SKEXP0001

using Microsoft.SemanticKernel.Agents.Orchestration.GroupChat;

var orchestration =
    new GroupChatOrchestration(
        new RoundRobinGroupChatManager()  { MaximumInvocationCount = 5  },
        generalDoctor,
        cardiologist,
        neurologist)
    {       
        ResponseCallback =  chatMessage => 
        { 
            groupChatHistory.Add(chatMessage);
            return ValueTask.CompletedTask;
        }
    };

// Start the runtime
var runtime = new InProcessRuntime();
await runtime.StartAsync();


OrchestrationResult<string> result = await orchestration.InvokeAsync("Everytime i workout my breath makes funny sounds. Tell me what to do", runtime);
string text = await result.GetValueAsync();
Console.WriteLine($"\n# RESULT: {text}");

await runtime.RunUntilIdleAsync();

Console.WriteLine("\n\nORCHESTRATION HISTORY");
foreach (ChatMessageContent message in groupChatHistory)
{
    DisplayResponse(message.AuthorName, message.Content);
}
# Out:
# # RESULT:
#
#
# ORCHESTRATION HISTORY
#
# 🤖 **GeneralDoctor:**
#    Thank you for sharing your concern. Based on your description, it is possible that your symptoms are related to exercise-induced bronchoconstriction (EIB), which can cause wheezing or "funny sounds" during workouts. Here is a general medical assessment:
#
# ### Potential Causes:
# 1. **Exercise-Induced Bronchoconstriction (EIB)**: Common in people with asthma or without a formal asthma diagnosis, especially during or after exercise.
# 2. **Upper Airway Issues**: Such as vocal cord dysfunction (VCD), which can mimic asthma symptoms.
# 3. **Sinus or Respiratory Conditions**: Chronic allergies, sinus infections, or postnasal drip could contribute to altered breathing sounds.
# 4. **Cardiopulmonary Concerns**: Rarely, abnormal breath sounds during exertion could indicate cardiac or pulmonary limitations.
#
# ### Recommended Steps:
# 1. **Schedule an Appointment**:
#    - Consult your primary care physician or a pulmonologist for a detailed evaluation.
#    - Consider referral to an allergist or ENT specialist if needed.
#
# 2. **Diagnostic Workup**:
#    - Spirometry or lung function testing (both at rest and post-exercise) to assess for EIB or other lung issues.
#    - If indicated, imaging studies like chest X-rays or CT scans.
#    - If suspected, testing for allergies that may impact your breathing.
#
# 3. **Treatment Options**:
#    - Use a bronchodilator (e.g., albuterol inhaler) 15-30 minutes before exercise, as prescribed by your doctor, if EIB is diagnosed.
#    - Breathing exercises or vocal therapy for managing potential vocal cord dysfunction.
#    - Overhaul environmental triggers (e.g., allergens or temperature extremes during workouts).
#
# 4. **Lifestyle Modifications**:
#    - Warm up before intense exercise.
#    - Avoid exercising in cold, dry environments, as they can exacerbate symptoms.
#
# Let us know more details about your symptoms for a refined assessment. Symptoms like chest tightness, coughing, or worsening breathing difficulties need immediate medical attention. Always seek direct evaluation if concerned.
# --------------------------------------------------
#
# 🤖 **Cardiologist:**
#    Given your description of experiencing "funny sounds" during workouts, it's critical to consider **potential cardiovascular causes** in addition to pulmonary concerns. As your team's dedicated cardiologist, I'll review cardiovascular factors that might contribute to such symptoms.
#
# ### Possible Cardiovascular Considerations:
# 1. **Exercise-Induced Cardiac Events**:
#    - **Left Ventricular Dysfunction**: Symptoms like wheezing sounds (cardiac asthma) or breathlessness during exertion can indicate issues with the heart's pumping ability.
#    - **Coronary Artery Disease (CAD)**: Inadequate blood supply during exercise could indirectly contribute to breath sounds due to pulmonary effects of reduced cardiac output.
#    - **Exercise-Induced Arrhythmias**: Abnormal heart rhythms during exercise could impair cardiac and respiratory coordination, leading to audible breath changes.
#
# 2. **Heart Failure**:
#    - Fluid accumulation in the lungs from mild heart failure can cause wheezing that mimics pulmonary asthma.
#    - Note whether you've experienced symptoms like swelling in the legs, consistent shortness of breath, or fatigue accompanying the "funny sounds."
#
# 3. **Pulmonary Hypertension**:
#    - Increased blood pressure in the lungs can occur during exertion, with symptoms including wheezing, breathlessness, or discomfort.
#
# 4. **Valvular Heart Disease**:
#    - Certain valve issues (e.g., aortic stenosis or mitral regurgitation) may impair blood flow and cause exertion-related respiratory sounds.
#
# ### Key Investigative Recommendations:
# - **Electrocardiogram (ECG)**: To check for underlying electrical or myocardial problems.
# - **Echocardiogram**: To assess heart structure and function, focusing on valvular issues and pulmonary pressures.
# - **Stress Test (Exercise ECG)**: Evaluate how your heart performs during physical activity.
# - **Biomarkers**: Blood tests like BNP/NT-proBNP to detect heart failure.
# - **Chest X-Ray**: To check for pulmonary vascular congestion.
#
# ### When to Seek Urgent Care:
# - If the "funny sounds" are accompanied by chest pain, lightheadedness, fainting, or excessive fatigue, seek immediate evaluation.
#
# ### Integration with Other Inputs:
# I recognize that pulmonary causes (like exercise-induced bronchoconstriction) were suggested by my colleagues. Wheezing sounds during workouts are frequently due to lung issues, but cardiac factors should not be ruled out prematurely. A collaborative evaluation between pulmonology and cardiology (along with additional testing) will be crucial to identifying the root cause.
#
# Let us know if you have symptoms such as chest heaviness, palpitations, or peripheral swelling, as this may guide us further toward cardiac considerations.
# --------------------------------------------------
#
# 🤖 **Nutritionist:**
#    Thank you for the inputs from both the pulmonology/general medical and cardiology perspectives. Now focusing on the **neurological aspects**, we need to consider whether your "funny sounds" during exercise stem from underlying nervous system or neuromuscular dysfunction. Here are possible neurological explanations and next steps:
#
# ---
#
# ### Neurological and Neuromuscular Considerations
# 1. **Central Regulation of Breathing**:
#    - The brainstem houses key respiratory centers that regulate breathing patterns. During strenuous exercise, any dysfunction in coordination or feedback mechanisms between the brainstem and respiratory muscles may cause abnormal breath sounds.
#    - If you have experienced other symptoms like dizziness, altered consciousness, or muscle coordination issues, there could be a central nervous system (CNS) component involved.
#
# 2. **Vocal Cord Dysfunction (VCD)**:
#    - Neurological control of the larynx may contribute to miscoordination of the vocal cords during high-demand activities, causing sounds like wheezing, stridor, or other unusual breath sounds during inhalation or exhalation.
#    - Symptoms might mimic asthma but would require specialized evaluation (e.g., laryngoscopy).
#
# 3. **Respiratory Muscle Coordination**:
#    - Central or peripheral nervous system conditions impairing the diaphragm or intercostal muscles could lead to altered breathing mechanics, resulting in these sounds.
#    - **Neuromuscular disorders**, such as myasthenia gravis or early-stage motor neuron disease, often initially manifest during periods of high exertion. For example:
#      - Difficulty maintaining heavy breathing during exercise.
#      - Weakness or fatigue localized to specific muscles after activity.
#
# 4. **Hyperventilation Syndromes**:
#    - Overactivation of the autonomic nervous system (e.g., associated with anxiety, stress, or dysautonomia) could lead to hyperventilation or altered breathing patterns, producing audible respiratory sounds.
#
# ---
#
# ### Neurological Diagnostic Recommendations
# 1. **Laryngoscopic Examination**:
#    - Prominent for assessing **vocal cord dysfunction** and ruling out neurological control disturbances.
#
# 2. **Neurological Exam**:
#    - Assess cranial nerves, muscle strength, reflexes, and coordination for possible neuromuscular contributions.
#
# 3. **Electromyography (EMG)**:
#    - To evaluate for conditions affecting the neuromuscular junction or muscles contributing to respiration.
#
# 4. **Brain and Spinal Imaging**:
#    - Consider MRI to check for central nervous system lesions if there are systemic neurological symptoms.
#
# 5. **Pulmonary Function with Neurological Perspective**:
#    - Test diaphragm strength and coordination during physiological stress tests.
#
# ---
#
# ### Integrated Plan
# - The primary suspicion lies in pulmonary causes (e.g., exercise-induced bronchoconstriction or upper airway dysfunction). However, if lung and cardiac evaluations are normal, neurological referral would be warranted to evaluate for:
#   - Vocal cord dysfunction (neurological etiology).
#   - Subtle neuromuscular disorders, especially affecting breathing patterns under stress.
#
# - **For Now**: Document precise descriptions of the sounds, when they occur (e.g., during inhalation vs. exhalation), and any accompanying systemic symptoms like muscle fatigue, coordination issues, or dizziness. This will help your healthcare team triangulate the root cause.
#
# Let me know if you have signs such as voice changes, swallowing difficulty, or worsening muscle fatigue—these may guide the next steps in diagnostics for neurological involvement.
# --------------------------------------------------
#
# 🤖 **GeneralDoctor:**
#    Thank you for the excellent multidisciplinary inputs. Here's a **summary of your healthcare team's insights** and the recommended approach:
#
# ### Summary of Medical Assessment:
# 1. **Pulmonary Causes**:
#    - Exercise-induced bronchoconstriction (EIB) or vocal cord dysfunction (VCD) are the most likely contributors to the "funny sounds" you notice during workouts.
#    - Relevant Testing: Spirometry, laryngoscopy, possible bronchodilator trial.
#
# 2. **Cardiovascular Causes**:
#    - Less likely but important to rule out—potential cardiac asthma, exercise-induced arrhythmias, or pulmonary hypertension.
#    - Relevant Testing: Cardiac stress tests, echocardiogram, biomarker assessments, chest X-rays.
#
# 3. **Neurological Causes**:
#    - Secondary suspicion of neuromuscular conditions or vocal cord miscoordination that may mimic asthma-like symptoms or altered breath sounds.
#    - Relevant Testing: Neurological exam, electromyography (EMG), or CNS imaging if systemic neurological symptoms appear.
#
# ---
#
# ### Recommended Next Steps for You:
# 1. **Step 1**: **Consult a Pulmonologist First**.
#    - Begin with investigating lung-related causes—exercise-induced bronchoconstriction (EIB), vocal cord dysfunction, or any anatomical airway issues. Consider spirometry and, if needed, laryngoscopic evaluation.
#
# 2. **Step 2**: **Cardiologist Review Based on Initial Findings**.
#    - If spirometry/lung tests are normal and symptoms persist with mild exertion, schedule a cardiac evaluation (stress test and echocardiogram).
#
# 3. **Step 3**: **Neurologist Referral If Unresolved**.
#    - Proceed with neurological testing if symptoms like vocal changes, swallowing issues, muscle fatigue, or coordination problems arise during workouts.
#
# 4. **Monitor and Record Symptoms**:
#    - Note the timing, duration, and specific triggers (e.g., intensity of exercise, environment, inhalation/exhalation impact) of the breathing sounds. This log can aid diagnostic precision.
#
# ---
#
# ### When to Seek Immediate Care:
# If you develop **chest pain, dizziness, fainting, significant shortness of breath, or difficulty swallowing**, seek urgent medical evaluation as these may indicate serious pulmonary, cardiac, or neurological concerns.
#
# Your primary team should include a **pulmonologist, cardiologist, and potentially an ENT specialist**, and later add a neurologist if all other evaluations are inconclusive. Let us know if you notice changes or additional symptoms!
# --------------------------------------------------
#
# 🤖 **Cardiologist:**
#    To summarize and provide clarity based on the inputs received so far:
#
# ### Primary Suspicions:
# 1. **Pulmonary Causes**:
#    - Exercise-induced bronchoconstriction is highly likely, given the description of breath sounds during workouts, especially if accompanied by wheezing or shortness of breath. This can be confirmed and managed with spirometry and a bronchodilator trial.
#    - Vocal Cord Dysfunction could mimic asthma-like symptoms (wheezing, audible breath sounds) during exertion. An ENT specialist might evaluate this with a laryngoscopic examination.
#
# 2. **Cardiovascular Causes**:
#    - **Heart failure**, pulmonary hypertension, or valvular heart disease could cause exertional respiratory sounds through fluid accumulation or impaired blood flow.
#    - If accompanied by exertional fatigue, chest discomfort, or swelling, further cardiac tests (ECG, echocardiogram, stress test) would be appropriate.
#
# 3. **Neurological/Neuromuscular Causes**:
#    - Subtle neuromuscular dysfunction (e.g., affecting the diaphragm or vocal cord control) could lead to abnormal breathing sounds. Neurological evaluation would come into play if pulmonary and cardiac evaluations are inconclusive.
#    - Psychological or autonomic dysregulation, such as hyperventilation syndromes during stress/exercise, could be a consideration.
#
# ---
#
# ### Next Steps Based on a Collaborative Approach:
# 1. **Start with Pulmonary Workup**:
#    - Spirometry at rest and post-exercise to evaluate airway reactivity.
#    - Consider a trial of bronchodilators before exercise as a potential immediate intervention to manage EIB.
#
# 2. **Include Cardiology Evaluation**:
#    - If symptoms persist or there are additional signs like chest tightness, fatigue, or swelling, start with cardiac tests (e.g., ECG, echo, stress test).
#    - Measure cardiac biomarkers like BNP if heart failure is suspected.
#
# 3. **Referral for ENT and Neurological Follow-Up**:
#    - Vocal cord dysfunction testing (laryngoscopy) if asthma and cardiac evaluations don't reveal a cause.
#    - Be vigilant for any associated neurological symptoms, such as muscle weakness or coordination difficulties, to warrant a neuromuscular workup.
#
# ---
#
# ### Lifestyle Modifications (General Advice):
# - Warm up properly before exercise.
# - Avoid cold or dry environments during workouts.
# - Document patterns in symptoms (e.g., time of day, intensity of exercise) to aid diagnostic focus.
# - Seek immediate care if you experience chest pain, fainting, palpitations, or unmanageable shortness of breath.
#
# Ultimately, an integrative diagnostic approach combining pulmonary, cardiac, and neurological insights should unravel the root cause of the "funny sounds." Stay proactive about follow-ups and update the team if new symptoms arise.
# --------------------------------------------------

# %% [markdown]
# ## Custom Orchestration
#
# Finally, let's explore **Custom Orchestration** - controlling the agents selection and termincation logic.
#
# ### Scenario: Hospital's Tumor Board 🎵
#
# Hospital's tumor board is reviewing a complex cancer case:

# %%
#pragma warning disable SKEXP0110
#pragma warning disable SKEXP0001

using Microsoft.SemanticKernel;
using Microsoft.SemanticKernel.Agents.Orchestration.GroupChat;
using Microsoft.SemanticKernel.ChatCompletion;

class TumorBoardLeader : GroupChatManager
{
    string _boardCase;
    IChatCompletionService _chatCompletion;

    public TumorBoardLeader(string boardCase, IChatCompletionService chatCompletion)
    {
        _boardCase = boardCase;
        _chatCompletion = chatCompletion;
    }

    private static class Prompts
    {
        public static string Termination(string boardCase) =>
            $"""
                You are a leader of the hospital tumor board. The case the board is working on is : '{boardCase}'. 
                You need to determine if the discussion has reached a conclusion and if all next steps were listed.
                if no artifacts were produced yet and you don't have knowledge of them yet, then continue the dicsussion and planning.
                
                If you would like to end the discussion, please respond with True. Otherwise, respond with False.
                """;

        public static string Selection(string boardCase, string participants) =>
            $"""
                Tou are a leader of the hospital tumor board. The case the board is working on is : '{boardCase}'. 
                You need to select the next team member to speak and suggest a plan or next steps. 
                Here are the roles and descriptions of the participants: 
                {participants}\n
                Please respond with only the role of the participant you would like to select.
                """;

        public static string Filter(string boardCase) =>
            $"""
                ou are a leader of the hospital tumor board. The case the board is working on is : '{boardCase}'. 
                You have just concluded the discussion and team work. 
                Please summarize the discussion and provide the final artifacts.
                """;
    }

    /// <inheritdoc/>
    public override ValueTask<GroupChatManagerResult<string>> FilterResults(ChatHistory history, CancellationToken cancellationToken = default) =>
        this.GetResponseAsync<string>(history, Prompts.Filter(_boardCase), cancellationToken);

    /// <inheritdoc/>
    public override ValueTask<GroupChatManagerResult<string>> SelectNextAgent(ChatHistory history, GroupChatTeam team, CancellationToken cancellationToken = default) =>
        this.GetResponseAsync<string>(history, Prompts.Selection(_boardCase, team.FormatList()), cancellationToken);

    /// <inheritdoc/>
    public override ValueTask<GroupChatManagerResult<bool>> ShouldRequestUserInput(ChatHistory history, CancellationToken cancellationToken = default) =>
        ValueTask.FromResult(new GroupChatManagerResult<bool>(false) { Reason = "The AI group chat manager does not request user input." });

    /// <inheritdoc/>
    public override async ValueTask<GroupChatManagerResult<bool>> ShouldTerminate(ChatHistory history, CancellationToken cancellationToken = default)
    {
        GroupChatManagerResult<bool> result = await base.ShouldTerminate(history, cancellationToken);
        if (!result.Value)
        {
            result = await this.GetResponseAsync<bool>(history, Prompts.Termination(_boardCase), cancellationToken);
        }
        return result;
    }

    private async ValueTask<GroupChatManagerResult<TValue>> GetResponseAsync<TValue>(ChatHistory history, string prompt, CancellationToken cancellationToken = default)
    {
        OpenAIPromptExecutionSettings executionSettings = new() { ResponseFormat = typeof(GroupChatManagerResult<TValue>) };
        ChatHistory request = [.. history, new ChatMessageContent(AuthorRole.System, prompt)];
        ChatMessageContent response = await _chatCompletion.GetChatMessageContentAsync(request, executionSettings, kernel: null, cancellationToken);
        string responseText = response.ToString();
        
        return
            JsonSerializer.Deserialize<GroupChatManagerResult<TValue>>(responseText) ??
            throw new InvalidOperationException($"Failed to parse response: {responseText}");
    }
}

# %%
DisplaySection("CUSTOM ORCHESTRATION - Hospital's tumor board is reviewing a complex cancer case", "🎵");

var oncologistAgent = new ChatCompletionAgent
{
    Name = "OncologistAgent",
    Instructions = 
        """
        You are a medical oncologist participating in a multidisciplinary discussion about a cancer patient's treatment. 
        Your role is to evaluate drug-based treatment options, considering cancer stage, biomarkers, and mutation data. 
        You collaborate with a radiologist and a pathologist. Be open to revising your recommendation based on their input.
        Only suggest treatments after reviewing all available clinical and diagnostic information.

        You are the final caller, the decision comes from you and you decide if more inputs are needed from the others.
        The final call and decision is yours! the result of the discussion should come from you so when you think the discussion is over, say it.
        """,
    Description = "A medical oncologist who suggests and revises treatment plans based on pathology and imaging insights.",
    Kernel = kernel,
    Arguments = new KernelArguments(new PromptExecutionSettings{ FunctionChoiceBehavior = FunctionChoiceBehavior.Auto(),})
};

var pathologistAgent = new ChatCompletionAgent
{
    Name = "PathologistAgent",
    Instructions = 
        """
        You are a clinical pathologist providing molecular and genetic analysis of a patient's tumor. 
        Share insights about mutations, biomarkers, and how they might affect treatment effectiveness. 
        Collaborate with the oncologist and radiologist. Suggest when additional lab tests may be needed.
        The final call and decision is of the oncologist!
        """,
    Description = "A clinical pathologist who interprets molecular and genetic data relevant to treatment decisions.",
    Kernel = kernel,
    Arguments = new KernelArguments(new PromptExecutionSettings{ FunctionChoiceBehavior = FunctionChoiceBehavior.Auto(),})

};

var radiologistAgent = new ChatCompletionAgent
{
    Name = "RadiologistAgent",
    Instructions = 
        """
        You are a radiologist interpreting imaging results for a cancer patient. 
        Point out any concerns such as lymph node involvement or metastasis. 
        Inform how imaging findings affect staging and treatment planning. Collaborate with the oncologist and pathologist.
        The final call and decision is of the oncologist!
        """,
    Description = "A radiologist who provides imaging-based insights and identifies implications for treatment planning.",
    Kernel = kernel,
    Arguments = new KernelArguments(new PromptExecutionSettings{ FunctionChoiceBehavior = FunctionChoiceBehavior.Auto(),})
};

// Create a shared chat history for the group consultation
var tumorBoardHistory = new ChatHistory();
# Out:
# 🎵 CUSTOM ORCHESTRATION - Hospital's tumor board is reviewing a complex cancer case
# ====================================================================================

# %%
#pragma warning disable SKEXP0110
#pragma warning disable SKEXP0001

using Microsoft.SemanticKernel.Agents.Orchestration;
using Microsoft.SemanticKernel.Agents.Runtime.InProcess;

string input =
    """
    Patient: Female, 55 years old  
    Diagnosis: Invasive ductal carcinoma, grade 3  
    Tumor Size: 2.8 cm  
    Stage: T2N0M0 (early-stage)  
    Hormone Receptors: ER+, PR+, HER2-  
    Ki-67: 35% (high proliferation)  
    Genetic Testing: BRCA-negative  
    Genomic Profile: PIK3CA mutation detected  
    Imaging: Mammogram and MRI confirm localized tumor, but one axillary lymph node appears suspicious (not biopsied yet)  
    Comorbidities: Mild hypertension  

    Please collaborate and determine the optimal treatment plan for this patient. Consider systemic therapies, genetic markers, and imaging findings. 
    Discuss whether further testing is needed, and iterate based on each other's input.
    The final call and decision is of the oncologist.
    """;


var chatCompletionService = kernel.GetRequiredService<IChatCompletionService>();

var tumorBoardOrchestration =
   new GroupChatOrchestration(
       new TumorBoardLeader(input, chatCompletionService),
       
       oncologistAgent, 
       pathologistAgent, 
       radiologistAgent)
   {
    ResponseCallback =  chatMessage => 
       { 
            DisplayResponse(chatMessage.AuthorName, chatMessage.Content);
            tumorBoardHistory.Add(chatMessage);
            return ValueTask.CompletedTask;  
       }
   };
// Start the runtime
InProcessRuntime runtime = new();
await runtime.StartAsync();



OrchestrationResult<string> result = await tumorBoardOrchestration.InvokeAsync(input, runtime);
string text = await result.GetValueAsync();
Console.WriteLine($"\n# RESULT: {text}");

await runtime.RunUntilIdleAsync();

Console.WriteLine("\n\nORCHESTRATION HISTORY");
foreach (ChatMessageContent message in tumorBoardHistory)
{
    DisplayResponse(message.AuthorName, message.Content);
}
# Out:
# 🤖 **RadiologistAgent:**
#    ### Imaging Analysis and Concerns
# From the imaging findings (mammogram and MRI), there are the following initial concerns:
# 1. **Primary Tumor**: Localized invasive ductal carcinoma measuring 2.8 cm without evidence of direct invasion of adjacent structures or distant metastases. Tumor size qualifies as T2 in the TNM staging system.
#
# 2. **Suspicious Axillary Lymph Node**: A single axillary lymph node appears suspicious on imaging, although it has not been biopsied yet. This creates a concern that the current classification of N0 may need revision. A biopsy is critical to confirm if this lymph node contains metastatic carcinoma, which would upstage the disease to N1 (T2N1M0).
#
# ---
#
# ### Impact on Staging and Treatment
# - If the axillary lymph node is positive for metastasis, the disease will upstage to **Stage IIB (T2N1M0)**.
# - This staging adjustment affects both **prognostication** and potential treatment intensification, especially in deciding between systemic adjuvant therapies and/or regional lymphatic control (e.g., radiation or sentinel node dissection).
#
# ---
#
# ### Recommendations for Further Testing
# 1. **Biopsy of Suspicious Lymph Node**: Ultrasound-guided or fine-needle aspiration (FNA) biopsy must be performed to confirm or rule out lymphatic involvement. This biopsy is critical for accurate staging and to determine whether additional treatments, such as axillary nodal dissection or intensification of systemic therapy, are needed.
#
# 2. **PIK3CA Mutation Implications**:
#    - The detected PIK3CA mutation is common in hormone receptor-positive HER2-negative breast cancers and has implications for treatment. Specifically, if the disease progresses or becomes metastatic, PI3K pathway inhibitors (e.g., alpelisib) in combination with endocrine therapy may be an option.
#
# 3. **Evaluate for Possible Distant Metastases**: Although no signs of metastasis were identified on current imaging, it is prudent to remain vigilant. If lymph node biopsy is positive, further imaging such as a PET-CT may be needed to evaluate for distant disease.
#
# ---
#
# ### Collaboration with Oncology and Pathology
# 1. **Medical Oncologist Input**:
#    - **Adjuvant Systemic Therapy**: Strong consideration for adjuvant chemotherapy is warranted due to high Ki-67 (35%), which indicates a highly proliferative tumor. This, in addition to endocrine therapy (e.g., tamoxifen or aromatase inhibitors), is a standard approach in ER+/PR+/HER2- cancers.
#    - If the lymph node is positive, chemotherapy may become even more crucial to reduce the risk of recurrence.
#    - Oncologists may also consider genomic assays (e.g., Oncotype DX or similar) to assess precise benefit from chemotherapy, though the high Ki-67 already suggests an aggressive representation.
#
# 2. **Radiation Therapy Needs**:
#    - Radiotherapy is typically recommended post-lumpectomy or for chest wall control after mastectomy in T2 tumors.
#    - If lymph node metastasis is confirmed, the field of radiation may need to include the axillary region for improved local regional control.
#
# 3. **Pathologist Input**: Pathological analysis of the lymph node biopsy will confirm whether the lymph node is involved and guide staging and treatment intensity.
#
# ---
#
# ### Treatment Options to Consider
# #### Current Stage: Early-Stage (T2N0M0)
# 1. **Surgery**:
#    - Breast-conserving surgery (e.g., lumpectomy) or mastectomy based on patient choice and tumor location.
#    - Sentinel lymph node biopsy during surgery is strongly indicated to assess nodal involvement definitively.
#
# 2. **Systemic Therapy**:
#    - Chemotherapy: Given the high Ki-67 (35%) and Grade 3 tumor, adjuvant chemotherapy is likely warranted in addition to endocrine therapy.
#    - Endocrine Therapy: Aromatase inhibitors or tamoxifen should be started post-therapy based on menopausal status.
#
# 3. **Radiation Therapy**:
#    - Post-lumpectomy radiation is required.
#    - If lymph nodes are positive, include axillary radiation.
#
# #### Upstaged Scenario: Stage IIB (T2N1M0 if node-positive)
# - The need for chemotherapy intensifies, as does nodal irradiation.
#
# ---
#
# ### Conclusion and Next Steps
# - The next critical step is **biopsy of the suspicious lymph node** for accurate staging.
# - Collaboration among the oncologist and pathologist is essential for determining the confirming diagnosis and scaling the treatment approach.
# - The final determination of the systemic and regional therapies will be made by the oncologist after the biopsy results, with a goal to balance efficacy with the patient’s specific risk factors and comorbidities (e.g., mild hypertension).
#
# Let’s proceed with the biopsy and refine the treatment plan based on the lymph node status.
# --------------------------------------------------
#
# # RESULT: ### Tumor Board Discussion Summary
#
# **Objective**: To determine the optimal treatment approach for a 55-year-old female with a diagnosis of stage T2N0M0 invasive ductal carcinoma (ER+, PR+, HER2-, Ki-67 35%), considering comorbid conditions, hormone receptor status, and genetic profiling results.
#
# ---
#
# **Key Findings and Recommendations**:
#
# 1. **Imaging and Staging Reevaluation**:
#    - Mammogram and MRI revealed a suspicious axillary lymph node. This finding necessitates further investigation to determine the extent of nodal involvement.
#    - Recommended Procedure: Biopsy of the suspicious lymph node for definitive staging (preferably via fine-needle aspiration or ultrasound-guided core biopsy).
#
# 2. **Surgery**:
#    - Proceed with breast-conserving surgery (lumpectomy) or mastectomy based on patient preference and tumor localization.
#    - Perform a sentinel lymph node biopsy during surgical excision to evaluate potential regional lymphatic involvement.
#
# 3. **Systemic Therapy**:
#    - Initiate adjuvant endocrine therapy with an aromatase inhibitor (postmenopausal) or tamoxifen based on hormone receptor positivity.
#    - Due to high Ki-67 and grade 3 histology, adjuvant chemotherapy is strongly considered to mitigate the risk of recurrence.
#    - Reserve targeted therapies for future consideration if needed, especially addressing the PIK3CA mutation should disease progression occur.
#
# 4. **Radiation Therapy**:
#    - Radiation therapy post-lumpectomy is advised to enhance local control.
#    - Extend radiation field to include the axillary region if lymph node involvement is confirmed.
#
# 5. **Supportive Care**:
#    - Manage the patient's mild hypertension promptly to optimize overall health prior to commencing treatment.
#
# ---
#
# **Consensus**: The board agrees that completion of the aforementioned diagnostic and therapeutic interventions represents the standard of care for this patient's condition. Final treatment planning will incorporate the biopsy results from the suspicious lymph node and patient’s preferences.
#
# ---
#
# The oncologist is requested to take these findings into consideration and finalize the treatment regimen after discussing with the patient.
#
#
# ORCHESTRATION HISTORY
#
# 🤖 **RadiologistAgent:**
#    ### Imaging Analysis and Concerns
# From the imaging findings (mammogram and MRI), there are the following initial concerns:
# 1. **Primary Tumor**: Localized invasive ductal carcinoma measuring 2.8 cm without evidence of direct invasion of adjacent structures or distant metastases. Tumor size qualifies as T2 in the TNM staging system.
#
# 2. **Suspicious Axillary Lymph Node**: A single axillary lymph node appears suspicious on imaging, although it has not been biopsied yet. This creates a concern that the current classification of N0 may need revision. A biopsy is critical to confirm if this lymph node contains metastatic carcinoma, which would upstage the disease to N1 (T2N1M0).
#
# ---
#
# ### Impact on Staging and Treatment
# - If the axillary lymph node is positive for metastasis, the disease will upstage to **Stage IIB (T2N1M0)**.
# - This staging adjustment affects both **prognostication** and potential treatment intensification, especially in deciding between systemic adjuvant therapies and/or regional lymphatic control (e.g., radiation or sentinel node dissection).
#
# ---
#
# ### Recommendations for Further Testing
# 1. **Biopsy of Suspicious Lymph Node**: Ultrasound-guided or fine-needle aspiration (FNA) biopsy must be performed to confirm or rule out lymphatic involvement. This biopsy is critical for accurate staging and to determine whether additional treatments, such as axillary nodal dissection or intensification of systemic therapy, are needed.
#
# 2. **PIK3CA Mutation Implications**:
#    - The detected PIK3CA mutation is common in hormone receptor-positive HER2-negative breast cancers and has implications for treatment. Specifically, if the disease progresses or becomes metastatic, PI3K pathway inhibitors (e.g., alpelisib) in combination with endocrine therapy may be an option.
#
# 3. **Evaluate for Possible Distant Metastases**: Although no signs of metastasis were identified on current imaging, it is prudent to remain vigilant. If lymph node biopsy is positive, further imaging such as a PET-CT may be needed to evaluate for distant disease.
#
# ---
#
# ### Collaboration with Oncology and Pathology
# 1. **Medical Oncologist Input**:
#    - **Adjuvant Systemic Therapy**: Strong consideration for adjuvant chemotherapy is warranted due to high Ki-67 (35%), which indicates a highly proliferative tumor. This, in addition to endocrine therapy (e.g., tamoxifen or aromatase inhibitors), is a standard approach in ER+/PR+/HER2- cancers.
#    - If the lymph node is positive, chemotherapy may become even more crucial to reduce the risk of recurrence.
#    - Oncologists may also consider genomic assays (e.g., Oncotype DX or similar) to assess precise benefit from chemotherapy, though the high Ki-67 already suggests an aggressive representation.
#
# 2. **Radiation Therapy Needs**:
#    - Radiotherapy is typically recommended post-lumpectomy or for chest wall control after mastectomy in T2 tumors.
#    - If lymph node metastasis is confirmed, the field of radiation may need to include the axillary region for improved local regional control.
#
# 3. **Pathologist Input**: Pathological analysis of the lymph node biopsy will confirm whether the lymph node is involved and guide staging and treatment intensity.
#
# ---
#
# ### Treatment Options to Consider
# #### Current Stage: Early-Stage (T2N0M0)
# 1. **Surgery**:
#    - Breast-conserving surgery (e.g., lumpectomy) or mastectomy based on patient choice and tumor location.
#    - Sentinel lymph node biopsy during surgery is strongly indicated to assess nodal involvement definitively.
#
# 2. **Systemic Therapy**:
#    - Chemotherapy: Given the high Ki-67 (35%) and Grade 3 tumor, adjuvant chemotherapy is likely warranted in addition to endocrine therapy.
#    - Endocrine Therapy: Aromatase inhibitors or tamoxifen should be started post-therapy based on menopausal status.
#
# 3. **Radiation Therapy**:
#    - Post-lumpectomy radiation is required.
#    - If lymph nodes are positive, include axillary radiation.
#
# #### Upstaged Scenario: Stage IIB (T2N1M0 if node-positive)
# - The need for chemotherapy intensifies, as does nodal irradiation.
#
# ---
#
# ### Conclusion and Next Steps
# - The next critical step is **biopsy of the suspicious lymph node** for accurate staging.
# - Collaboration among the oncologist and pathologist is essential for determining the confirming diagnosis and scaling the treatment approach.
# - The final determination of the systemic and regional therapies will be made by the oncologist after the biopsy results, with a goal to balance efficacy with the patient’s specific risk factors and comorbidities (e.g., mild hypertension).
#
# Let’s proceed with the biopsy and refine the treatment plan based on the lymph node status.
# --------------------------------------------------
